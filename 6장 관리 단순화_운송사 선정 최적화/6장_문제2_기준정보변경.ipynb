# %% [markdown]
# # 6장 문제2B. 관리 단순화를 위한 운송사 선정 최적화(기준정보변경)
# - 문제1 + 최대운송사개수 제약
# - 50개 운송사 기준정보 변경

# %%
# !pip install pulp
# Out:
# Collecting pulp
#   Downloading pulp-3.1.1-py3-none-any.whl.metadata (1.3 kB)
# Downloading pulp-3.1.1-py3-none-any.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 54.1 MB/s eta 0:00:00
# Installing collected packages: pulp
# Successfully installed pulp-3.1.1

# %%
import pandas as pd
import time
import pulp
from pulp import LpProblem, LpMinimize, LpVariable, lpSum, LpInteger, value

def optimize_truck_assignment():
    start_time = time.time()

    #--------------------------------------------------------
    # 1) 엑셀에서 데이터 읽어오기
    #--------------------------------------------------------
    input_file = "/content/sample_data/50개운송사_기준정보.xlsx"

    # A~E열: (운송사, 운송구간, 트럭유형, 운송단가, 트럭대수)
    df = pd.read_excel(input_file, sheet_name=0, usecols="A:E")

    # H~J열: (운송구간, 트럭유형, 필요대수)
    df_demand = pd.read_excel(input_file, sheet_name=0, usecols="H:J")
    df_demand.columns = ['운송구간', '트럭유형', '필요대수']

    # M열: 최대 선택 가능한 운송사 수
    max_trucker_num = pd.read_excel(input_file, sheet_name=0, usecols="M").iloc[0, 0]

    # 데이터 클리닝
    df['운송단가'] = pd.to_numeric(df['운송단가'], errors='coerce')
    df['트럭대수'] = pd.to_numeric(df['트럭대수'], errors='coerce')
    df_demand['필요대수'] = pd.to_numeric(df_demand['필요대수'], errors='coerce')

    df.dropna(subset=['운송단가', '트럭대수'], inplace=True)
    df_demand.dropna(subset=['필요대수'], inplace=True)

    #--------------------------------------------------------
    # 2) 파라미터 구성
    #--------------------------------------------------------
    cost_dict = {}      # {(운송사, 구간, 트럭유형): 단가}
    capacity_dict = {}  # {(운송사, 구간, 트럭유형): 트럭대수}
    for _, row in df.iterrows():
        key = (row['운송사'], row['운송구간'], row['트럭유형'])
        cost_dict[key] = row['운송단가']
        capacity_dict[key] = row['트럭대수']

    demand_dict = {}    # {(구간, 트럭유형): 필요대수}
    for _, row in df_demand.iterrows():
        key = (row['운송구간'], row['트럭유형'])
        demand_dict[key] = row['필요대수']

    truckers = df['운송사'].unique()
    route_type_list = demand_dict.keys()

    #--------------------------------------------------------
    # 3) PuLP 모델 생성
    #--------------------------------------------------------
    prob = LpProblem("Truck_Optimization", LpMinimize)

    #--------------------------------------------------------
    # 4) 결정변수
    #--------------------------------------------------------
    x_vars = {}
    for (i, r, t), cost in cost_dict.items():
        x_vars[(i, r, t)] = LpVariable(f"x_{i}_{r}_{t}", lowBound=0, cat=LpInteger)

    y_vars = {i: LpVariable(f"y_{i}", cat='Binary') for i in truckers}

    #--------------------------------------------------------
    # 5) 목적함수: 총 운송비 최소화
    #--------------------------------------------------------
    prob += lpSum([cost_dict[(i, r, t)] * x_vars[(i, r, t)] for (i, r, t) in cost_dict]), "Minimize_TotalCost"

    #--------------------------------------------------------
    # 6) 제약조건
    #--------------------------------------------------------
    # (1) 각 (구간, 트럭유형)에 대한 필요대수 충족
    for (r, t) in route_type_list:
        prob += lpSum([x_vars[(i, r, t)] for i in truckers if (i, r, t) in x_vars]) == demand_dict[(r, t)], f"Demand_{r}_{t}"

    # (2) 각 운송사별 보유 트럭 수 제한
    for (i, r, t), capacity in capacity_dict.items():
        prob += x_vars[(i, r, t)] <= capacity, f"Capacity_{i}_{r}_{t}"

    # (3) 운송사가 선택되었을 경우에만 트럭 배정
    for i in truckers:
        for (r, t) in route_type_list:
            if (i, r, t) in x_vars:
                prob += x_vars[(i, r, t)] <= capacity_dict[(i, r, t)] * y_vars[i], f"Truck_Selection_{i}_{r}_{t}"

    # (4) 선택된 운송사 수 제한
    prob += lpSum([y_vars[i] for i in truckers]) <= max_trucker_num, "Max_Truckers"

    #--------------------------------------------------------
    # 7) 최적화 실행
    #--------------------------------------------------------
    prob.solve(pulp.PULP_CBC_CMD(msg=0))
    status = prob.status

    print("Status:", pulp.LpStatus[status])
    if status not in [1, 2]:
        print("=> 유효한 해를 찾지 못했습니다.")
        return

    total_cost = value(prob.objective)
    print("총 운송비:", total_cost)

    #--------------------------------------------------------
    # 8) 결과 정리 및 저장
    #--------------------------------------------------------
    result_data = []
    for (i, r, t), var in x_vars.items():
        if var.varValue > 0:
            result_data.append([i, r, t, cost_dict[(i, r, t)], int(var.varValue)])

    df_result = pd.DataFrame(result_data, columns=['운송사', '운송구간', '트럭유형', '운송단가', '선택된트럭수'])
    df_result.sort_values(by=['운송구간', '트럭유형'], inplace=True)

    output_file = "/content/sample_data/문제2최적화결과_50개운송사.xlsx"
    df_result.to_excel(output_file, index=False)

    print("\n--- 배정 결과 ---")
    print(df_result.to_string(index=False))

    end_time = time.time()
    print("\n프로그램 수행시간(초):", round(end_time - start_time, 4))


if __name__ == "__main__":
    optimize_truck_assignment()
# Out:
# Status: Optimal
# 총 운송비: 927180.0
#
# --- 배정 결과 ---
#   운송사 운송구간 트럭유형  운송단가  선택된트럭수
# 운송사13 구간01 트럭01   131      30
# 운송사07 구간01 트럭02   157      30
# 운송사38 구간01 트럭03   167      30
# 운송사29 구간01 트럭04   153      30
# 운송사17 구간02 트럭01   191      30
# 운송사07 구간02 트럭02   174      30
# 운송사07 구간02 트럭03   155      30
# 운송사22 구간02 트럭04   114      30
# 운송사21 구간03 트럭01   111      30
# 운송사13 구간03 트럭02   122      30
# 운송사38 구간03 트럭03   168      30
# 운송사29 구간03 트럭04   146      30
# 운송사22 구간04 트럭01   152      30
# 운송사07 구간04 트럭02   151      30
# 운송사17 구간04 트럭03   138      30
# 운송사24 구간04 트럭04   109      30
# 운송사07 구간05 트럭01   117      30
# 운송사31 구간05 트럭02   114      30
# 운송사17 구간05 트럭03   290      30
# 운송사31 구간05 트럭04   246      30
# 운송사07 구간06 트럭01   159      30
# 운송사24 구간06 트럭02   123      30
# 운송사22 구간06 트럭03   157      30
# 운송사13 구간06 트럭04   220      30
# 운송사22 구간07 트럭01   132      30
# 운송사38 구간07 트럭02   144      30
# 운송사31 구간07 트럭03   233      30
# 운송사31 구간07 트럭04   260      30
# 운송사22 구간08 트럭01   171      30
# 운송사29 구간08 트럭02   126      30
# 운송사21 구간08 트럭03   120      30
# 운송사38 구간08 트럭04   104      30
# 운송사38 구간09 트럭01   106      30
# 운송사07 구간09 트럭02   168      30
# 운송사29 구간09 트럭03   105      30
# 운송사31 구간09 트럭04   104      30
# 운송사29 구간10 트럭01   178      30
# 운송사29 구간10 트럭02   173      30
# 운송사31 구간10 트럭03   240      30
# 운송사22 구간10 트럭04   112      30
# 운송사21 구간11 트럭01   143      30
# 운송사21 구간11 트럭02   160      30
# 운송사13 구간11 트럭03   154      30
# 운송사47 구간11 트럭04   178      30
# 운송사24 구간12 트럭01   141      30
# 운송사07 구간12 트럭02   181      30
# 운송사07 구간12 트럭03   110      30
# 운송사24 구간12 트럭04   107      30
# 운송사21 구간13 트럭01   238      30
# 운송사29 구간13 트럭02   137      30
# 운송사38 구간13 트럭03   107      30
# 운송사21 구간13 트럭04   171      30
# 운송사38 구간14 트럭01   228      30
# 운송사24 구간14 트럭02   132      30
# 운송사31 구간14 트럭03   159      30
# 운송사22 구간14 트럭04   125      30
# 운송사21 구간15 트럭01   180      30
# 운송사13 구간15 트럭02   118      30
# 운송사13 구간15 트럭03   164      30
# 운송사38 구간15 트럭04   223      30
# 운송사21 구간16 트럭01   351      30
# 운송사24 구간16 트럭02   138      30
# 운송사13 구간16 트럭03   154      30
# 운송사21 구간16 트럭04   161      30
# 운송사07 구간17 트럭01   150      30
# 운송사38 구간17 트럭02   101      30
# 운송사38 구간17 트럭03   162      30
# 운송사24 구간17 트럭04   120      30
# 운송사38 구간18 트럭01   249      30
# 운송사07 구간18 트럭02   144      30
# 운송사13 구간18 트럭03   105      30
# 운송사13 구간18 트럭04   191      30
# 운송사22 구간19 트럭01   115      30
# 운송사47 구간19 트럭02   111      30
# 운송사47 구간19 트럭03   101      30
# 운송사17 구간19 트럭04   108      30
# 운송사24 구간20 트럭01   156      30
# 운송사29 구간20 트럭02   124      30
# 운송사13 구간20 트럭03   174      30
# 운송사47 구간20 트럭04   110      30
# 운송사24 구간21 트럭01   104      30
# 운송사24 구간21 트럭02   109      30
# 운송사31 구간21 트럭03   185      30
# 운송사24 구간21 트럭04   147      30
# 운송사31 구간22 트럭01   107      30
# 운송사22 구간22 트럭02   196      30
# 운송사13 구간22 트럭03   101      30
# 운송사07 구간22 트럭04   204      30
# 운송사29 구간23 트럭01   112      30
# 운송사17 구간23 트럭02   110      30
# 운송사29 구간23 트럭03   261      30
# 운송사22 구간23 트럭04   124      30
# 운송사29 구간24 트럭01   192      30
# 운송사47 구간24 트럭02   142      30
# 운송사38 구간24 트럭03   116      30
# 운송사24 구간24 트럭04   110      30
# 운송사17 구간25 트럭01   155      30
# 운송사13 구간25 트럭02   144      30
# 운송사31 구간25 트럭03   105      30
# 운송사31 구간25 트럭04   153      30
# 운송사24 구간26 트럭01   147      30
# 운송사24 구간26 트럭02   203      30
# 운송사13 구간26 트럭03   104      30
# 운송사21 구간26 트럭04   143      30
# 운송사29 구간27 트럭01   154      30
# 운송사21 구간27 트럭02   293      30
# 운송사38 구간27 트럭03   349      30
# 운송사21 구간27 트럭04   238      30
# 운송사17 구간28 트럭01   102      30
# 운송사47 구간28 트럭02   185      30
# 운송사47 구간28 트럭03   137      30
# 운송사24 구간28 트럭04   195      30
# 운송사29 구간29 트럭01   194      30
# 운송사22 구간29 트럭02   160      30
# 운송사17 구간29 트럭03   293      30
# 운송사47 구간29 트럭04   133      30
# 운송사31 구간30 트럭01   105      30
# 운송사22 구간30 트럭02   124      30
# 운송사38 구간30 트럭03   144      30
# 운송사29 구간30 트럭04   198      30
# 운송사21 구간31 트럭01   122      30
# 운송사38 구간31 트럭02   131      30
# 운송사22 구간31 트럭03   133      30
# 운송사13 구간31 트럭04   184      30
# 운송사47 구간32 트럭01   170      30
# 운송사07 구간32 트럭02   115      30
# 운송사47 구간32 트럭03   202      30
# 운송사22 구간32 트럭04   144      30
# 운송사47 구간33 트럭01   245      30
# 운송사29 구간33 트럭02   133      30
# 운송사47 구간33 트럭03   111      30
# 운송사17 구간33 트럭04   119      30
# 운송사13 구간34 트럭01   170      30
# 운송사31 구간34 트럭02   162      30
# 운송사31 구간34 트럭03   146      30
# 운송사07 구간34 트럭04   140      30
# 운송사38 구간35 트럭01   291      30
# 운송사24 구간35 트럭02   146      30
# 운송사17 구간35 트럭03   133      30
# 운송사22 구간35 트럭04   140      30
# 운송사24 구간36 트럭01   119      30
# 운송사47 구간36 트럭02   215      30
# 운송사13 구간36 트럭03   139      30
# 운송사31 구간36 트럭04   112      30
# 운송사07 구간37 트럭01   138      30
# 운송사22 구간37 트럭02   251      30
# 운송사24 구간37 트럭03   137      30
# 운송사38 구간37 트럭04   123      30
# 운송사38 구간38 트럭01   193      30
# 운송사17 구간38 트럭02   138      30
# 운송사24 구간38 트럭03   162      30
# 운송사17 구간38 트럭04   159      30
# 운송사22 구간39 트럭01   101      30
# 운송사31 구간39 트럭02   212      30
# 운송사22 구간39 트럭03   102      30
# 운송사47 구간39 트럭04   104      30
# 운송사13 구간40 트럭01   154      30
# 운송사38 구간40 트럭02   270      30
# 운송사31 구간40 트럭03   143      30
# 운송사29 구간40 트럭04   113      30
# 운송사38 구간41 트럭01   140      30
# 운송사29 구간41 트럭02   175      30
# 운송사38 구간41 트럭03   121      30
# 운송사22 구간41 트럭04   103      30
# 운송사38 구간42 트럭01   188      30
# 운송사17 구간42 트럭02   109      30
# 운송사17 구간42 트럭03   116      30
# 운송사21 구간42 트럭04   123      30
# 운송사07 구간43 트럭01   126      30
# 운송사22 구간43 트럭02   123      30
# 운송사47 구간43 트럭03   188      30
# 운송사29 구간43 트럭04   142      30
# 운송사21 구간44 트럭01   140      30
# 운송사31 구간44 트럭02   101      30
# 운송사13 구간44 트럭03   204      30
# 운송사47 구간44 트럭04   112      30
# 운송사21 구간45 트럭01   135      30
# 운송사24 구간45 트럭02   146      30
# 운송사31 구간45 트럭03   192      30
# 운송사47 구간45 트럭04   183      30
# 운송사24 구간46 트럭01   110      30
# 운송사22 구간46 트럭02   145      30
# 운송사22 구간46 트럭03   109      30
# 운송사24 구간46 트럭04   247      30
# 운송사13 구간47 트럭01   155      30
# 운송사29 구간47 트럭02   268      30
# 운송사13 구간47 트럭03   124      30
# 운송사07 구간47 트럭04   100      30
# 운송사47 구간48 트럭01   104      30
# 운송사47 구간48 트럭02   195      30
# 운송사22 구간48 트럭03   151      30
# 운송사38 구간48 트럭04   145      30
# 운송사13 구간49 트럭01   100      30
# 운송사07 구간49 트럭02   130      30
# 운송사17 구간49 트럭03   147      30
# 운송사31 구간49 트럭04   168      30
# 운송사21 구간50 트럭01   128      30
# 운송사13 구간50 트럭02   110      30
# 운송사07 구간50 트럭03   131      30
# 운송사38 구간50 트럭04   150      30
#
# 프로그램 수행시간(초): 227.115
