# %% [markdown]
# # **ortools 라이브러리를 활용하여 최적화하자**

# %% [markdown]
# 문제3 운송사 최대배정 제한 제약조건을 반영한 '리스크 분산을 위한 운송사 선정 최적화'와 변형문제를 ortools라이브러리를 이용하여 구함
#
# (동일 프로그램에서 입출력 파일명만 변경)
#
# 1) 3개운송사_할당제약_기준정보
#
# 2) 3개운송사_3개운송구간_기준정보
#
# 3) 4개운송사_3개운송구간_기준정보
#
# 4) 1개운송사만선정_기준정보

# %%
# !pip install ortools
# Out:
# Requirement already satisfied: ortools in /usr/local/lib/python3.11/dist-packages (9.14.6206)
# Requirement already satisfied: absl-py>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ortools) (2.3.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.11/dist-packages (from ortools) (2.0.2)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ortools) (2.2.2)
# Requirement already satisfied: protobuf<6.32,>=6.31.1 in /usr/local/lib/python3.11/dist-packages (from ortools) (6.31.1)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from ortools) (4.14.1)
# Requirement already satisfied: immutabledict>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from ortools) (4.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->ortools) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->ortools) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->ortools) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->ortools) (1.17.0)

# %% [markdown]
# 3개운송사_할당제약_기준정보

# %%
import pandas as pd
import time
import math
from ortools.linear_solver import pywraplp

def optimize_truck_assignment():
    start_time = time.time()

    #--------------------------------------------------------
    # 1) 데이터 불러오기
    #--------------------------------------------------------
    input_file = "/content/sample_data/3개운송사_할당제약_기준정보.xlsx"
    df = pd.read_excel(input_file, sheet_name=0, usecols="A:E")
    df_demand = pd.read_excel(input_file, sheet_name=0, usecols="H:J")
    df_demand.columns = ['운송구간', '트럭유형', '필요대수']
    max_trucker_num = int(pd.read_excel(input_file, sheet_name=0, usecols="M").iloc[0, 0])
    max_ratio = float(pd.read_excel(input_file, sheet_name=0, usecols="P").iloc[0, 0])

    # 결측값 제거 및 숫자 변환
    df['운송단가'] = pd.to_numeric(df['운송단가'], errors='coerce')
    df['트럭대수'] = pd.to_numeric(df['트럭대수'], errors='coerce')
    df.dropna(subset=['운송단가', '트럭대수'], inplace=True)

    df_demand['필요대수'] = pd.to_numeric(df_demand['필요대수'], errors='coerce')
    df_demand.dropna(subset=['필요대수'], inplace=True)

    #--------------------------------------------------------
    # 2) 파라미터 세팅
    #--------------------------------------------------------
    cost_dict = {}      # (i, r, t): 운송단가
    capacity_dict = {}  # (i, r, t): 트럭보유대수
    for _, row in df.iterrows():
        key = (row['운송사'], row['운송구간'], row['트럭유형'])
        cost_dict[key] = row['운송단가']
        capacity_dict[key] = row['트럭대수']

    demand_dict = {}    # (r, t): 필요대수
    for _, row in df_demand.iterrows():
        key = (row['운송구간'], row['트럭유형'])
        demand_dict[key] = row['필요대수']

    truckers = df['운송사'].unique()
    route_type_list = demand_dict.keys()

    #--------------------------------------------------------
    # 3) OR-Tools 모델 생성
    #--------------------------------------------------------
    solver = pywraplp.Solver.CreateSolver('CBC')
    if not solver:
        print("Solver 초기화 실패")
        return

    #--------------------------------------------------------
    # 4) 변수 정의
    #--------------------------------------------------------
    x_vars = {}  # 트럭 수 변수
    for (i, r, t), cost in cost_dict.items():
        x_vars[(i, r, t)] = solver.IntVar(0, capacity_dict[(i, r, t)], f"x_{i}_{r}_{t}")

    y_vars = {i: solver.BoolVar(f"y_{i}") for i in truckers}

    #--------------------------------------------------------
    # 5) 목적함수: 총 운송비 최소화
    #--------------------------------------------------------
    solver.Minimize(solver.Sum(cost_dict[(i, r, t)] * x_vars[(i, r, t)] for (i, r, t) in x_vars))

    #--------------------------------------------------------
    # 6) 제약조건 추가
    #--------------------------------------------------------

    # (1) 수요 충족
    for (r, t) in route_type_list:
        solver.Add(solver.Sum(x_vars[(i, r, t)] for i in truckers if (i, r, t) in x_vars) == demand_dict[(r, t)])

    # (2) 트럭 보유량 이내로 배정
    for (i, r, t), cap in capacity_dict.items():
        solver.Add(x_vars[(i, r, t)] <= cap)

    # (3) 운송사 선택 여부에 따라 트럭 배정 가능
    for (i, r, t) in x_vars:
        solver.Add(x_vars[(i, r, t)] <= capacity_dict[(i, r, t)] * y_vars[i])

    # (4) 선택된 운송사 수 제한
    solver.Add(solver.Sum(y_vars[i] for i in truckers) <= max_trucker_num)

    # (5) 운송사당 최대 배정량 제한 (X_MAX 적용)
    for (r, t) in route_type_list:
        demand = demand_dict[(r, t)]
        x_max = math.ceil(demand * max_ratio)
        for i in truckers:
            if (i, r, t) in x_vars:
                solver.Add(x_vars[(i, r, t)] <= x_max)

    #--------------------------------------------------------
    # 7) 최적화 실행
    #--------------------------------------------------------
    status = solver.Solve()

    if status not in [pywraplp.Solver.OPTIMAL, pywraplp.Solver.FEASIBLE]:
        print("=> 유효한 해를 찾지 못했습니다.")
        return

    total_cost = solver.Objective().Value()
    print("총 운송비:", total_cost)

    #--------------------------------------------------------
    # 8) 결과 저장
    #--------------------------------------------------------
    result_data = []
    for (i, r, t), var in x_vars.items():
        val = var.solution_value()
        if val > 0:
            result_data.append([i, r, t, cost_dict[(i, r, t)], int(val)])

    df_result = pd.DataFrame(result_data, columns=['운송사', '운송구간', '트럭유형', '운송단가', '선택된트럭수'])
    df_result.sort_values(by=['운송구간', '트럭유형'], inplace=True)

    output_file = "/content/sample_data/3개운송사_할당제약_최적화결과.xlsx"
    df_result.to_excel(output_file, index=False)

    print("\n--- 배정 결과 ---")
    print(df_result.to_string(index=False))

    end_time = time.time()
    print("\n프로그램 수행시간(초):", round(end_time - start_time, 4))

if __name__ == "__main__":
    optimize_truck_assignment()
# Out:
# 총 운송비: 7800.0
#
# --- 배정 결과 ---
#   운송사 운송구간 트럭유형  운송단가  선택된트럭수
# 운송사01 구간01 트럭01   100       8
# 운송사03 구간01 트럭01   200       2
# 운송사01 구간01 트럭02   100       8
# 운송사03 구간01 트럭02   200       2
# 운송사01 구간02 트럭01   100       8
# 운송사03 구간02 트럭01   200       2
# 운송사01 구간02 트럭02   500       2
# 운송사03 구간02 트럭02   400       8
#
# 프로그램 수행시간(초): 0.7352

# %% [markdown]
# # **변형된 문제를 가지고 결괏값을 검증하자**

# %% [markdown]
# 3개운송사-3개운송구간_기준정보

# %%
import pandas as pd
import time
import math
from ortools.linear_solver import pywraplp

def optimize_truck_assignment():
    start_time = time.time()

    #--------------------------------------------------------
    # 1) 데이터 불러오기
    #--------------------------------------------------------
    input_file = "/content/sample_data/3개운송사_3개운송구간_기준정보.xlsx"
    df = pd.read_excel(input_file, sheet_name=0, usecols="A:E")
    df_demand = pd.read_excel(input_file, sheet_name=0, usecols="H:J")
    df_demand.columns = ['운송구간', '트럭유형', '필요대수']
    max_trucker_num = int(pd.read_excel(input_file, sheet_name=0, usecols="M").iloc[0, 0])
    max_ratio = float(pd.read_excel(input_file, sheet_name=0, usecols="P").iloc[0, 0])

    # 결측값 제거 및 숫자 변환
    df['운송단가'] = pd.to_numeric(df['운송단가'], errors='coerce')
    df['트럭대수'] = pd.to_numeric(df['트럭대수'], errors='coerce')
    df.dropna(subset=['운송단가', '트럭대수'], inplace=True)

    df_demand['필요대수'] = pd.to_numeric(df_demand['필요대수'], errors='coerce')
    df_demand.dropna(subset=['필요대수'], inplace=True)

    #--------------------------------------------------------
    # 2) 파라미터 세팅
    #--------------------------------------------------------
    cost_dict = {}      # (i, r, t): 운송단가
    capacity_dict = {}  # (i, r, t): 트럭보유대수
    for _, row in df.iterrows():
        key = (row['운송사'], row['운송구간'], row['트럭유형'])
        cost_dict[key] = row['운송단가']
        capacity_dict[key] = row['트럭대수']

    demand_dict = {}    # (r, t): 필요대수
    for _, row in df_demand.iterrows():
        key = (row['운송구간'], row['트럭유형'])
        demand_dict[key] = row['필요대수']

    truckers = df['운송사'].unique()
    route_type_list = demand_dict.keys()

    #--------------------------------------------------------
    # 3) OR-Tools 모델 생성
    #--------------------------------------------------------
    solver = pywraplp.Solver.CreateSolver('CBC')
    if not solver:
        print("Solver 초기화 실패")
        return

    #--------------------------------------------------------
    # 4) 변수 정의
    #--------------------------------------------------------
    x_vars = {}  # 트럭 수 변수
    for (i, r, t), cost in cost_dict.items():
        x_vars[(i, r, t)] = solver.IntVar(0, capacity_dict[(i, r, t)], f"x_{i}_{r}_{t}")

    y_vars = {i: solver.BoolVar(f"y_{i}") for i in truckers}

    #--------------------------------------------------------
    # 5) 목적함수: 총 운송비 최소화
    #--------------------------------------------------------
    solver.Minimize(solver.Sum(cost_dict[(i, r, t)] * x_vars[(i, r, t)] for (i, r, t) in x_vars))

    #--------------------------------------------------------
    # 6) 제약조건 추가
    #--------------------------------------------------------

    # (1) 수요 충족
    for (r, t) in route_type_list:
        solver.Add(solver.Sum(x_vars[(i, r, t)] for i in truckers if (i, r, t) in x_vars) == demand_dict[(r, t)])

    # (2) 트럭 보유량 이내로 배정
    for (i, r, t), cap in capacity_dict.items():
        solver.Add(x_vars[(i, r, t)] <= cap)

    # (3) 운송사 선택 여부에 따라 트럭 배정 가능
    for (i, r, t) in x_vars:
        solver.Add(x_vars[(i, r, t)] <= capacity_dict[(i, r, t)] * y_vars[i])

    # (4) 선택된 운송사 수 제한
    solver.Add(solver.Sum(y_vars[i] for i in truckers) <= max_trucker_num)

    # (5) 운송사당 최대 배정량 제한 (X_MAX 적용)
    for (r, t) in route_type_list:
        demand = demand_dict[(r, t)]
        x_max = math.ceil(demand * max_ratio)
        for i in truckers:
            if (i, r, t) in x_vars:
                solver.Add(x_vars[(i, r, t)] <= x_max)

    #--------------------------------------------------------
    # 7) 최적화 실행
    #--------------------------------------------------------
    status = solver.Solve()

    if status not in [pywraplp.Solver.OPTIMAL, pywraplp.Solver.FEASIBLE]:
        print("=> 유효한 해를 찾지 못했습니다.")
        return

    total_cost = solver.Objective().Value()
    print("총 운송비:", total_cost)

    #--------------------------------------------------------
    # 8) 결과 저장
    #--------------------------------------------------------
    result_data = []
    for (i, r, t), var in x_vars.items():
        val = var.solution_value()
        if val > 0:
            result_data.append([i, r, t, cost_dict[(i, r, t)], int(val)])

    df_result = pd.DataFrame(result_data, columns=['운송사', '운송구간', '트럭유형', '운송단가', '선택된트럭수'])
    df_result.sort_values(by=['운송구간', '트럭유형'], inplace=True)

    output_file = "/content/sample_data/3개운송사_3개운송구간_최적화결과.xlsx"
    df_result.to_excel(output_file, index=False)

    print("\n--- 배정 결과 ---")
    print(df_result.to_string(index=False))

    end_time = time.time()
    print("\n프로그램 수행시간(초):", round(end_time - start_time, 4))

if __name__ == "__main__":
    optimize_truck_assignment()
# Out:
# 총 운송비: 32200.0
#
# --- 배정 결과 ---
#   운송사 운송구간 트럭유형  운송단가  선택된트럭수
# 운송사02 구간01 트럭01   150       8
# 운송사03 구간01 트럭01   200       2
# 운송사02 구간01 트럭02   150       8
# 운송사03 구간01 트럭02   200       2
# 운송사02 구간02 트럭01   150       8
# 운송사03 구간02 트럭01   200       2
# 운송사02 구간02 트럭02 10000       2
# 운송사03 구간02 트럭02   400       8
# 운송사02 구간03 트럭01   400       8
# 운송사03 구간03 트럭01   500       2
#
# 프로그램 수행시간(초): 0.0695

# %% [markdown]
# 4개운송사_3개운송구간_기준정보

# %%
import pandas as pd
import time
import math
from ortools.linear_solver import pywraplp

def optimize_truck_assignment():
    start_time = time.time()

    #--------------------------------------------------------
    # 1) 데이터 불러오기
    #--------------------------------------------------------
    input_file = "/content/sample_data/4개운송사_3개운송구간_기준정보.xlsx"
    df = pd.read_excel(input_file, sheet_name=0, usecols="A:E")
    df_demand = pd.read_excel(input_file, sheet_name=0, usecols="H:J")
    df_demand.columns = ['운송구간', '트럭유형', '필요대수']
    max_trucker_num = int(pd.read_excel(input_file, sheet_name=0, usecols="M").iloc[0, 0])
    max_ratio = float(pd.read_excel(input_file, sheet_name=0, usecols="P").iloc[0, 0])

    # 결측값 제거 및 숫자 변환
    df['운송단가'] = pd.to_numeric(df['운송단가'], errors='coerce')
    df['트럭대수'] = pd.to_numeric(df['트럭대수'], errors='coerce')
    df.dropna(subset=['운송단가', '트럭대수'], inplace=True)

    df_demand['필요대수'] = pd.to_numeric(df_demand['필요대수'], errors='coerce')
    df_demand.dropna(subset=['필요대수'], inplace=True)

    #--------------------------------------------------------
    # 2) 파라미터 세팅
    #--------------------------------------------------------
    cost_dict = {}      # (i, r, t): 운송단가
    capacity_dict = {}  # (i, r, t): 트럭보유대수
    for _, row in df.iterrows():
        key = (row['운송사'], row['운송구간'], row['트럭유형'])
        cost_dict[key] = row['운송단가']
        capacity_dict[key] = row['트럭대수']

    demand_dict = {}    # (r, t): 필요대수
    for _, row in df_demand.iterrows():
        key = (row['운송구간'], row['트럭유형'])
        demand_dict[key] = row['필요대수']

    truckers = df['운송사'].unique()
    route_type_list = demand_dict.keys()

    #--------------------------------------------------------
    # 3) OR-Tools 모델 생성
    #--------------------------------------------------------
    solver = pywraplp.Solver.CreateSolver('CBC')
    if not solver:
        print("Solver 초기화 실패")
        return

    #--------------------------------------------------------
    # 4) 변수 정의
    #--------------------------------------------------------
    x_vars = {}  # 트럭 수 변수
    for (i, r, t), cost in cost_dict.items():
        x_vars[(i, r, t)] = solver.IntVar(0, capacity_dict[(i, r, t)], f"x_{i}_{r}_{t}")

    y_vars = {i: solver.BoolVar(f"y_{i}") for i in truckers}

    #--------------------------------------------------------
    # 5) 목적함수: 총 운송비 최소화
    #--------------------------------------------------------
    solver.Minimize(solver.Sum(cost_dict[(i, r, t)] * x_vars[(i, r, t)] for (i, r, t) in x_vars))

    #--------------------------------------------------------
    # 6) 제약조건 추가
    #--------------------------------------------------------

    # (1) 수요 충족
    for (r, t) in route_type_list:
        solver.Add(solver.Sum(x_vars[(i, r, t)] for i in truckers if (i, r, t) in x_vars) == demand_dict[(r, t)])

    # (2) 트럭 보유량 이내로 배정
    for (i, r, t), cap in capacity_dict.items():
        solver.Add(x_vars[(i, r, t)] <= cap)

    # (3) 운송사 선택 여부에 따라 트럭 배정 가능
    for (i, r, t) in x_vars:
        solver.Add(x_vars[(i, r, t)] <= capacity_dict[(i, r, t)] * y_vars[i])

    # (4) 선택된 운송사 수 제한
    solver.Add(solver.Sum(y_vars[i] for i in truckers) <= max_trucker_num)

    # (5) 운송사당 최대 배정량 제한 (X_MAX 적용)
    for (r, t) in route_type_list:
        demand = demand_dict[(r, t)]
        x_max = math.ceil(demand * max_ratio)
        for i in truckers:
            if (i, r, t) in x_vars:
                solver.Add(x_vars[(i, r, t)] <= x_max)

    #--------------------------------------------------------
    # 7) 최적화 실행
    #--------------------------------------------------------
    status = solver.Solve()

    if status not in [pywraplp.Solver.OPTIMAL, pywraplp.Solver.FEASIBLE]:
        print("=> 유효한 해를 찾지 못했습니다.")
        return

    total_cost = solver.Objective().Value()
    print("총 운송비:", total_cost)

    #--------------------------------------------------------
    # 8) 결과 저장
    #--------------------------------------------------------
    result_data = []
    for (i, r, t), var in x_vars.items():
        val = var.solution_value()
        if val > 0:
            result_data.append([i, r, t, cost_dict[(i, r, t)], int(val)])

    df_result = pd.DataFrame(result_data, columns=['운송사', '운송구간', '트럭유형', '운송단가', '선택된트럭수'])
    df_result.sort_values(by=['운송구간', '트럭유형'], inplace=True)

    output_file = "/content/sample_data/4개운송사_3개운송구간_최적화결과.xlsx"
    df_result.to_excel(output_file, index=False)

    print("\n--- 배정 결과 ---")
    print(df_result.to_string(index=False))

    end_time = time.time()
    print("\n프로그램 수행시간(초):", round(end_time - start_time, 4))

if __name__ == "__main__":
    optimize_truck_assignment()
# Out:
# => 유효한 해를 찾지 못했습니다.

# %% [markdown]
# 1개운송사만선정_기준정보

# %%
import pandas as pd
import time
import math
from ortools.linear_solver import pywraplp

def optimize_truck_assignment():
    start_time = time.time()

    #--------------------------------------------------------
    # 1) 데이터 불러오기
    #--------------------------------------------------------
    input_file = "/content/sample_data/1개운송사만선정_기준정보.xlsx"
    df = pd.read_excel(input_file, sheet_name=0, usecols="A:E")
    df_demand = pd.read_excel(input_file, sheet_name=0, usecols="H:J")
    df_demand.columns = ['운송구간', '트럭유형', '필요대수']
    max_trucker_num = int(pd.read_excel(input_file, sheet_name=0, usecols="M").iloc[0, 0])
    max_ratio = float(pd.read_excel(input_file, sheet_name=0, usecols="P").iloc[0, 0])

    # 결측값 제거 및 숫자 변환
    df['운송단가'] = pd.to_numeric(df['운송단가'], errors='coerce')
    df['트럭대수'] = pd.to_numeric(df['트럭대수'], errors='coerce')
    df.dropna(subset=['운송단가', '트럭대수'], inplace=True)

    df_demand['필요대수'] = pd.to_numeric(df_demand['필요대수'], errors='coerce')
    df_demand.dropna(subset=['필요대수'], inplace=True)

    #--------------------------------------------------------
    # 2) 파라미터 세팅
    #--------------------------------------------------------
    cost_dict = {}      # (i, r, t): 운송단가
    capacity_dict = {}  # (i, r, t): 트럭보유대수
    for _, row in df.iterrows():
        key = (row['운송사'], row['운송구간'], row['트럭유형'])
        cost_dict[key] = row['운송단가']
        capacity_dict[key] = row['트럭대수']

    demand_dict = {}    # (r, t): 필요대수
    for _, row in df_demand.iterrows():
        key = (row['운송구간'], row['트럭유형'])
        demand_dict[key] = row['필요대수']

    truckers = df['운송사'].unique()
    route_type_list = demand_dict.keys()

    #--------------------------------------------------------
    # 3) OR-Tools 모델 생성
    #--------------------------------------------------------
    solver = pywraplp.Solver.CreateSolver('CBC')
    if not solver:
        print("Solver 초기화 실패")
        return

    #--------------------------------------------------------
    # 4) 변수 정의
    #--------------------------------------------------------
    x_vars = {}  # 트럭 수 변수
    for (i, r, t), cost in cost_dict.items():
        x_vars[(i, r, t)] = solver.IntVar(0, capacity_dict[(i, r, t)], f"x_{i}_{r}_{t}")

    y_vars = {i: solver.BoolVar(f"y_{i}") for i in truckers}

    #--------------------------------------------------------
    # 5) 목적함수: 총 운송비 최소화
    #--------------------------------------------------------
    solver.Minimize(solver.Sum(cost_dict[(i, r, t)] * x_vars[(i, r, t)] for (i, r, t) in x_vars))

    #--------------------------------------------------------
    # 6) 제약조건 추가
    #--------------------------------------------------------

    # (1) 수요 충족
    for (r, t) in route_type_list:
        solver.Add(solver.Sum(x_vars[(i, r, t)] for i in truckers if (i, r, t) in x_vars) == demand_dict[(r, t)])

    # (2) 트럭 보유량 이내로 배정
    for (i, r, t), cap in capacity_dict.items():
        solver.Add(x_vars[(i, r, t)] <= cap)

    # (3) 운송사 선택 여부에 따라 트럭 배정 가능
    for (i, r, t) in x_vars:
        solver.Add(x_vars[(i, r, t)] <= capacity_dict[(i, r, t)] * y_vars[i])

    # (4) 선택된 운송사 수 제한
    solver.Add(solver.Sum(y_vars[i] for i in truckers) <= max_trucker_num)

    # (5) 운송사당 최대 배정량 제한 (X_MAX 적용)
    for (r, t) in route_type_list:
        demand = demand_dict[(r, t)]
        x_max = math.ceil(demand * max_ratio)
        for i in truckers:
            if (i, r, t) in x_vars:
                solver.Add(x_vars[(i, r, t)] <= x_max)

    #--------------------------------------------------------
    # 7) 최적화 실행
    #--------------------------------------------------------
    status = solver.Solve()

    if status not in [pywraplp.Solver.OPTIMAL, pywraplp.Solver.FEASIBLE]:
        print("=> 유효한 해를 찾지 못했습니다.")
        return

    total_cost = solver.Objective().Value()
    print("총 운송비:", total_cost)

    #--------------------------------------------------------
    # 8) 결과 저장
    #--------------------------------------------------------
    result_data = []
    for (i, r, t), var in x_vars.items():
        val = var.solution_value()
        if val > 0:
            result_data.append([i, r, t, cost_dict[(i, r, t)], int(val)])

    df_result = pd.DataFrame(result_data, columns=['운송사', '운송구간', '트럭유형', '운송단가', '선택된트럭수'])
    df_result.sort_values(by=['운송구간', '트럭유형'], inplace=True)

    output_file = "/content/sample_data/1개운송사만선정_최적화결과.xlsx"
    df_result.to_excel(output_file, index=False)

    print("\n--- 배정 결과 ---")
    print(df_result.to_string(index=False))

    end_time = time.time()
    print("\n프로그램 수행시간(초):", round(end_time - start_time, 4))

if __name__ == "__main__":
    optimize_truck_assignment()
# Out:
# 총 운송비: 108500.0
#
# --- 배정 결과 ---
#   운송사 운송구간 트럭유형  운송단가  선택된트럭수
# 운송사02 구간01 트럭01   150      10
# 운송사02 구간01 트럭02   150      10
# 운송사02 구간02 트럭01   150      10
# 운송사02 구간02 트럭02 10000      10
# 운송사02 구간03 트럭01   400      10
#
# 프로그램 수행시간(초): 0.0735

# %% [markdown]
# # **큰 크기의 문제를 풀어보자**
# - 큰 크기의 문제를 풀기전 사전 정제된 데이터로 테스트(100개 운송사 1차 전처리 후 데이터)
# - 100개운송사_50개운송구간_기준정보A선행결과통합.xlsx 에 대하여 약 28분 소요

# %%
import pandas as pd
import time
import math
from ortools.linear_solver import pywraplp

def optimize_truck_assignment():
    start_time = time.time()

    #--------------------------------------------------------
    # 1) 데이터 불러오기
    #--------------------------------------------------------
    input_file = "/content/sample_data/100개운송사_50개운송구간_기준정보A선행결과통합.xlsx"
    df = pd.read_excel(input_file, sheet_name=0, usecols="A:E")
    df_demand = pd.read_excel(input_file, sheet_name=0, usecols="H:J")
    df_demand.columns = ['운송구간', '트럭유형', '필요대수']
    max_trucker_num = int(pd.read_excel(input_file, sheet_name=0, usecols="M").iloc[0, 0])
    max_ratio = float(pd.read_excel(input_file, sheet_name=0, usecols="P").iloc[0, 0])

    # 결측값 제거 및 숫자 변환
    df['운송단가'] = pd.to_numeric(df['운송단가'], errors='coerce')
    df['트럭대수'] = pd.to_numeric(df['트럭대수'], errors='coerce')
    df.dropna(subset=['운송단가', '트럭대수'], inplace=True)

    df_demand['필요대수'] = pd.to_numeric(df_demand['필요대수'], errors='coerce')
    df_demand.dropna(subset=['필요대수'], inplace=True)

    #--------------------------------------------------------
    # 2) 파라미터 세팅
    #--------------------------------------------------------
    cost_dict = {}      # (i, r, t): 운송단가
    capacity_dict = {}  # (i, r, t): 트럭보유대수
    for _, row in df.iterrows():
        key = (row['운송사'], row['운송구간'], row['트럭유형'])
        cost_dict[key] = row['운송단가']
        capacity_dict[key] = row['트럭대수']

    demand_dict = {}    # (r, t): 필요대수
    for _, row in df_demand.iterrows():
        key = (row['운송구간'], row['트럭유형'])
        demand_dict[key] = row['필요대수']

    truckers = df['운송사'].unique()
    route_type_list = demand_dict.keys()

    #--------------------------------------------------------
    # 3) OR-Tools 모델 생성
    #--------------------------------------------------------
    solver = pywraplp.Solver.CreateSolver('CBC')
    if not solver:
        print("Solver 초기화 실패")
        return

    #--------------------------------------------------------
    # 4) 변수 정의
    #--------------------------------------------------------
    x_vars = {}  # 트럭 수 변수
    for (i, r, t), cost in cost_dict.items():
        x_vars[(i, r, t)] = solver.IntVar(0, capacity_dict[(i, r, t)], f"x_{i}_{r}_{t}")

    y_vars = {i: solver.BoolVar(f"y_{i}") for i in truckers}

    #--------------------------------------------------------
    # 5) 목적함수: 총 운송비 최소화
    #--------------------------------------------------------
    solver.Minimize(solver.Sum(cost_dict[(i, r, t)] * x_vars[(i, r, t)] for (i, r, t) in x_vars))

    #--------------------------------------------------------
    # 6) 제약조건 추가
    #--------------------------------------------------------

    # (1) 수요 충족
    for (r, t) in route_type_list:
        solver.Add(solver.Sum(x_vars[(i, r, t)] for i in truckers if (i, r, t) in x_vars) == demand_dict[(r, t)])

    # (2) 트럭 보유량 이내로 배정
    for (i, r, t), cap in capacity_dict.items():
        solver.Add(x_vars[(i, r, t)] <= cap)

    # (3) 운송사 선택 여부에 따라 트럭 배정 가능
    for (i, r, t) in x_vars:
        solver.Add(x_vars[(i, r, t)] <= capacity_dict[(i, r, t)] * y_vars[i])

    # (4) 선택된 운송사 수 제한
    solver.Add(solver.Sum(y_vars[i] for i in truckers) <= max_trucker_num)

    # (5) 운송사당 최대 배정량 제한 (X_MAX 적용)
    for (r, t) in route_type_list:
        demand = demand_dict[(r, t)]
        x_max = math.ceil(demand * max_ratio)
        for i in truckers:
            if (i, r, t) in x_vars:
                solver.Add(x_vars[(i, r, t)] <= x_max)

    #--------------------------------------------------------
    # 7) 최적화 실행
    #--------------------------------------------------------
    status = solver.Solve()

    if status not in [pywraplp.Solver.OPTIMAL, pywraplp.Solver.FEASIBLE]:
        print("=> 유효한 해를 찾지 못했습니다.")
        return

    total_cost = solver.Objective().Value()
    print("총 운송비:", total_cost)

    #--------------------------------------------------------
    # 8) 결과 저장
    #--------------------------------------------------------
    result_data = []
    for (i, r, t), var in x_vars.items():
        val = var.solution_value()
        if val > 0:
            result_data.append([i, r, t, cost_dict[(i, r, t)], int(val)])

    df_result = pd.DataFrame(result_data, columns=['운송사', '운송구간', '트럭유형', '운송단가', '선택된트럭수'])
    df_result.sort_values(by=['운송구간', '트럭유형'], inplace=True)

    output_file = "/content/sample_data/100개운송사_50개운송구간_기준정보A선행결과통합_최적화결과.xlsx"
    df_result.to_excel(output_file, index=False)

    print("\n--- 배정 결과 ---")
    print(df_result.to_string(index=False))

    end_time = time.time()
    print("\n프로그램 수행시간(초):", round(end_time - start_time, 4))

if __name__ == "__main__":
    optimize_truck_assignment()
# Out:
# 총 운송비: 990450.0
#
# --- 배정 결과 ---
#   운송사 운송구간 트럭유형  운송단가  선택된트럭수
# 운송사59 구간01 트럭01   213       3
# 운송사74 구간01 트럭01   147      27
# 운송사41 구간01 트럭02   176      27
# 운송사46 구간01 트럭02   391       3
# 운송사54 구간01 트럭03   270       3
# 운송사58 구간01 트럭03   147      27
# 운송사46 구간01 트럭04   152       3
# 운송사62 구간01 트럭04   107      27
# 운송사58 구간02 트럭01   301       3
# 운송사62 구간02 트럭01   248      27
# 운송사41 구간02 트럭02   194      27
# 운송사62 구간21 트럭04   116       3
# 운송사41 구간22 트럭01   329       3
# 운송사51 구간22 트럭01   165      27
# 운송사46 구간22 트럭02   252       3
# 운송사54 구간22 트럭02   193      27
# 운송사54 구간22 트럭03   186      27
# 운송사58 구간22 트럭03   257       3
# 운송사42 구간22 트럭04   128      27
# 운송사74 구간22 트럭04   261       3
# 운송사44 구간23 트럭01   261      27
# 운송사46 구간23 트럭01   310       3
# 운송사62 구간23 트럭02   159      27
# 운송사74 구간23 트럭02   172       3
# 운송사54 구간23 트럭03   562       3
# 운송사74 구간23 트럭03   316      27
# 운송사42 구간23 트럭04   159       3
# 운송사51 구간23 트럭04   132      27
# 운송사44 구간24 트럭01   412       3
# 운송사51 구간24 트럭01   130      27
# 운송사58 구간24 트럭02   110      27
# 운송사62 구간24 트럭02   189       3
# 운송사44 구간24 트럭03   247       3
# 운송사58 구간24 트럭03   172      27
# 운송사41 구간24 트럭04   154       3
# 운송사62 구간24 트럭04   101      27
# 운송사54 구간25 트럭01   295       3
# 운송사58 구간25 트럭01   164      27
# 운송사51 구간25 트럭02   176       3
# 운송사74 구간25 트럭02   140      27
# 운송사58 구간25 트럭03   270       3
# 운송사74 구간25 트럭03   193      27
# 운송사42 구간25 트럭04   171      27
# 운송사74 구간25 트럭04   179       3
# 운송사46 구간26 트럭01   186       3
# 운송사74 구간26 트럭01   134      27
# 운송사42 구간26 트럭02   202       3
# 운송사62 구간26 트럭02   121      27
# 운송사51 구간26 트럭03   136       3
# 운송사74 구간26 트럭03   128      27
# 운송사42 구간26 트럭04   321       3
# 운송사59 구간26 트럭04   182      27
# 운송사58 구간27 트럭01   170       3
# 운송사59 구간27 트럭01   105      27
# 운송사44 구간27 트럭02   269       3
# 운송사51 구간27 트럭02   137      27
# 운송사46 구간27 트럭03   476       3
# 운송사62 구간27 트럭03   145      27
# 운송사42 구간27 트럭04   162       3
# 운송사58 구간27 트럭04   160      27
# 운송사42 구간28 트럭01   318       3
# 운송사58 구간28 트럭01   102      27
# 운송사42 구간28 트럭02   192      27
# 운송사46 구간28 트럭02   211       3
# 운송사41 구간28 트럭03   196       3
# 운송사44 구간28 트럭03   185      27
# 운송사44 구간28 트럭04   401       3
# 운송사59 구간28 트럭04   102      27
# 운송사41 구간29 트럭01   259       3
# 운송사54 구간29 트럭01   137      27
# 운송사42 구간29 트럭02   206      27
# 운송사54 구간29 트럭02   210       3
# 운송사41 구간29 트럭03   178       3
# 운송사51 구간29 트럭03   127      27
# 운송사54 구간29 트럭04   297      27
# 운송사59 구간29 트럭04   364       3
# 운송사41 구간30 트럭01   149       3
# 운송사42 구간30 트럭01   126      27
# 운송사41 구간30 트럭02   104      27
# 운송사74 구간30 트럭02   186       3
# 운송사51 구간30 트럭03   136       3
# 운송사74 구간30 트럭03   116      27
# 운송사41 구간30 트럭04   118       3
# 운송사46 구간30 트럭04   108      27
# 운송사42 구간31 트럭01   361       3
# 운송사46 구간31 트럭01   259      27
# 운송사44 구간31 트럭02   176      27
# 운송사51 구간31 트럭02   222       3
# 운송사44 구간31 트럭03   151      27
# 운송사59 구간41 트럭02   192       3
# 운송사58 구간41 트럭03   223       3
# 운송사59 구간41 트럭03   135      27
# 운송사46 구간41 트럭04   103      27
# 운송사62 구간41 트럭04   281       3
# 운송사41 구간42 트럭01   240      27
# 운송사62 구간42 트럭01   429       3
# 운송사41 구간42 트럭02   102      27
# 운송사59 구간42 트럭02   211       3
# 운송사54 구간42 트럭03   130      27
# 운송사62 구간42 트럭03   353       3
# 운송사44 구간42 트럭04   185      27
# 운송사54 구간42 트럭04   413       3
# 운송사44 구간43 트럭01   200       3
# 운송사51 구간43 트럭01   160      27
# 운송사54 구간43 트럭02   267       3
# 운송사62 구간43 트럭02   160      27
# 운송사42 구간43 트럭03   422       3
# 운송사74 구간43 트럭03   249      27
# 운송사42 구간43 트럭04   156       3
# 운송사51 구간43 트럭04   121      27
# 운송사46 구간44 트럭01   111      27
# 운송사74 구간44 트럭01   120       3
# 운송사51 구간44 트럭02   102      27
# 운송사59 구간44 트럭02   306       3
# 운송사54 구간44 트럭03   241      27
# 운송사74 구간44 트럭03   359       3
# 운송사44 구간44 트럭04   115      27
# 운송사51 구간44 트럭04   207       3
# 운송사42 구간45 트럭01   109      27
# 운송사59 구간45 트럭01   157       3
# 운송사44 구간45 트럭02   313       3
# 운송사62 구간45 트럭02   176      27
# 운송사46 구간45 트럭03   148       3
# 운송사58 구간45 트럭03   121      27
# 운송사44 구간45 트럭04   376       3
# 운송사59 구간45 트럭04   179      27
# 운송사41 구간46 트럭01   284       3
# 운송사51 구간46 트럭01   214      27
# 운송사44 구간46 트럭02   154      27
# 운송사59 구간46 트럭02   283       3
# 운송사51 구간46 트럭03   133      27
# 운송사59 구간46 트럭03   376       3
# 운송사41 구간46 트럭04   112      27
# 운송사58 구간46 트럭04   182       3
# 운송사42 구간47 트럭01   136      27
# 운송사62 구간47 트럭01   274       3
# 운송사41 구간47 트럭02   135      27
# 운송사74 구간47 트럭02   151       3
# 운송사42 구간47 트럭03   363       3
# 운송사62 구간47 트럭03   145      27
# 운송사42 구간47 트럭04   180      27
# 운송사59 구간47 트럭04   305       3
# 운송사41 구간48 트럭01   214      27
# 운송사46 구간48 트럭01   260       3
# 운송사44 구간48 트럭02   185       3
# 운송사74 구간48 트럭02   102      27
# 운송사51 구간48 트럭03   196       3
# 운송사54 구간48 트럭03   180      27
# 운송사54 구간48 트럭04   225      27
# 운송사62 구간48 트럭04   355       3
# 운송사59 구간49 트럭01   134      27
# 운송사62 구간49 트럭01   246       3
# 운송사46 구간49 트럭02   108      27
# 운송사74 구간49 트럭02   350       3
# 운송사54 구간49 트럭03   139       3
# 운송사58 구간49 트럭03   125      27
# 운송사59 구간49 트럭04   102      27
# 운송사74 구간49 트럭04   218       3
# 운송사44 구간50 트럭01   171       3
# 운송사54 구간50 트럭01   154      27
# 운송사41 구간50 트럭02   331       3
# 운송사62 구간50 트럭02   109      27
# 운송사42 구간50 트럭03   363       3
# 운송사58 구간50 트럭03   101      27
# 운송사42 구간50 트럭04   150       3
# 운송사62 구간50 트럭04   125      27
#
# 프로그램 수행시간(초): 1692.1771
